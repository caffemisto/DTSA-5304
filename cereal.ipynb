# %%
import pandas as pd

data= pd.read_csv("cereal.csv", header = 0)
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
import altair as alt

# %%
alt.Chart(data).mark_circle().encode(x="sodium", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="fat", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="fiber", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="carbo", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="sugars", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="potass", y="calories")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(x="calories", y="rating", color = "mfr")
# Out:
# alt.Chart(...)
